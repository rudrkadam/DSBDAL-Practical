# %% [markdown]
# ## Python / Subsets / Iris dataset

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd

# %%
# Reading dataset into a pandas dataframe

df = pd.read_csv('Iris.csv')
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# Columns in the dataset

df.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'species']
print(df)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# Description of dataframe

df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Creating a subset for different species

# %%
# Unique species in the dataset

x = pd.unique(df['species'])
x
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Subset for specoes 'Iris-virginica'

subset1 = df.loc[df['species'] == 'Iris-virginica']
subset1
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 99            6.3          3.3           6.0          2.5  Iris-virginica
# 100           5.8          2.7           5.1          1.9  Iris-virginica
# 101           7.1          3.0           5.9          2.1  Iris-virginica
# 102           6.3          2.9           5.6          1.8  Iris-virginica
# 103           6.5          3.0           5.8          2.2  Iris-virginica
# 104           7.6          3.0           6.6          2.1  Iris-virginica
# 105           4.9          2.5           4.5          1.7  Iris-virginica
# 106           7.3          2.9           6.3          1.8  Iris-virginica
# 107           6.7          2.5           5.8          1.8  Iris-virginica
# 108           7.2          3.6           6.1          2.5  Iris-virginica
# 109           6.5          3.2           5.1          2.0  Iris-virginica
# 110           6.4          2.7           5.3          1.9  Iris-virginica
# ...

# %%
# Subset for species 'Iris-versicolor'

subset2 = df.loc[df['species'] == 'Iris-versicolor']
subset2
# Out:
#     sepal length  sepal width  petal length  petal width          species
# 49           7.0          3.2           4.7          1.4  Iris-versicolor
# 50           6.4          3.2           4.5          1.5  Iris-versicolor
# 51           6.9          3.1           4.9          1.5  Iris-versicolor
# 52           5.5          2.3           4.0          1.3  Iris-versicolor
# 53           6.5          2.8           4.6          1.5  Iris-versicolor
# 54           5.7          2.8           4.5          1.3  Iris-versicolor
# 55           6.3          3.3           4.7          1.6  Iris-versicolor
# 56           4.9          2.4           3.3          1.0  Iris-versicolor
# 57           6.6          2.9           4.6          1.3  Iris-versicolor
# 58           5.2          2.7           3.9          1.4  Iris-versicolor
# 59           5.0          2.0           3.5          1.0  Iris-versicolor
# 60           5.9          3.0           4.2          1.5  Iris-versicolor
# ...

# %%
# Subset for species 'Iris-setosa'

subset3 = df.loc[df['species'] == 'Iris-setosa']
subset3
# Out:
#     sepal length  sepal width  petal length  petal width      species
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           1.6          0.2  Iris-setosa
# 11           4.8          3.0           1.4          0.1  Iris-setosa
# ...

# %% [markdown]
# ### Merging subsets

# %%
merge_ds = pd.merge(subset1, subset2, on = 'sepal length', how = 'inner')
merge_ds
# Out:
#     sepal length  sepal width_x  petal length_x  petal width_x  \
# 0            6.3            3.3             6.0            2.5
# 1            6.3            3.3             6.0            2.5
# 2            6.3            3.3             6.0            2.5
# 3            6.3            2.9             5.6            1.8
# 4            6.3            2.9             5.6            1.8
# ..           ...            ...             ...            ...
# 89           6.1            2.6             5.6            1.4
# 90           6.1            2.6             5.6            1.4
# 91           6.1            2.6             5.6            1.4
# 92           5.9            3.0             5.1            1.8
# 93           5.9            3.0             5.1            1.8
#
#          species_x  sepal width_y  petal length_y  petal width_y  \
# 0   Iris-virginica            3.3             4.7            1.6
# 1   Iris-virginica            2.5             4.9            1.5
# ...

# %%
merge_ds2 = pd.merge(subset2, subset3, on = 'sepal width', how = 'inner')
merge_ds2
# Out:
#     sepal length_x  sepal width  petal length_x  petal width_x  \
# 0              7.0          3.2             4.7            1.4
# 1              7.0          3.2             4.7            1.4
# 2              7.0          3.2             4.7            1.4
# 3              7.0          3.2             4.7            1.4
# 4              7.0          3.2             4.7            1.4
# ..             ...          ...             ...            ...
# 94             6.0          3.4             4.5            1.6
# 95             6.0          3.4             4.5            1.6
# 96             6.0          3.4             4.5            1.6
# 97             6.0          3.4             4.5            1.6
# 98             6.0          3.4             4.5            1.6
#
#           species_x  sepal length_y  petal length_y  petal width_y  \
# 0   Iris-versicolor             4.7             1.3            0.2
# 1   Iris-versicolor             4.7             1.6            0.2
# ...

# %% [markdown]
# ### Sorting data on petal length

# %%
sorted_data = df.sort_values(by = ['petal length'], ascending = True)
sorted_data
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 21            4.6          3.6           1.0          0.2     Iris-setosa
# 12            4.3          3.0           1.1          0.1     Iris-setosa
# 34            5.0          3.2           1.2          0.2     Iris-setosa
# 13            5.8          4.0           1.2          0.2     Iris-setosa
# 37            4.4          3.0           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 130           7.9          3.8           6.4          2.0  Iris-virginica
# 104           7.6          3.0           6.6          2.1  Iris-virginica
# 121           7.7          2.8           6.7          2.0  Iris-virginica
# 116           7.7          3.8           6.7          2.2  Iris-virginica
# 117           7.7          2.6           6.9          2.3  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Transposing data

# %%
transpose_data = df.transpose()
transpose_data
# Out:
#                       0            1            2            3            4    \
# sepal length          4.9          4.7          4.6          5.0          5.4
# sepal width           3.0          3.2          3.1          3.6          3.9
# petal length          1.4          1.3          1.5          1.4          1.7
# petal width           0.2          0.2          0.2          0.2          0.4
# species       Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                       5            6            7            8            9    \
# sepal length          4.6          5.0          4.4          4.9          5.4
# sepal width           3.4          3.4          2.9          3.1          3.7
# petal length          1.4          1.5          1.4          1.5          1.5
# petal width           0.3          0.2          0.2          0.1          0.2
# species       Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
# ...

# %% [markdown]
# ### Melting data to long format

# %%
melted_df = pd.melt(frame = df, id_vars=['sepal length','petal length','species'])
melted_df
# Out:
#      sepal length  petal length         species     variable  value
# 0             4.9           1.4     Iris-setosa  sepal width    3.0
# 1             4.7           1.3     Iris-setosa  sepal width    3.2
# 2             4.6           1.5     Iris-setosa  sepal width    3.1
# 3             5.0           1.4     Iris-setosa  sepal width    3.6
# 4             5.4           1.7     Iris-setosa  sepal width    3.9
# ..            ...           ...             ...          ...    ...
# 293           6.7           5.2  Iris-virginica  petal width    2.3
# 294           6.3           5.0  Iris-virginica  petal width    1.9
# 295           6.5           5.2  Iris-virginica  petal width    2.0
# 296           6.2           5.4  Iris-virginica  petal width    2.3
# 297           5.9           5.1  Iris-virginica  petal width    1.8
#
# [298 rows x 5 columns]

# %% [markdown]
# ### Casting data to wide format

# %%
casted_df = df.pivot_table(df, index = ['species'])
casted_df
# Out:
#                  petal length  petal width  sepal length  sepal width
# species
# Iris-setosa          1.465306     0.244898      5.004082     3.416327
# Iris-versicolor      4.260000     1.326000      5.936000     2.770000
# Iris-virginica       5.552000     2.026000      6.588000     2.974000
